# %% [markdown]
# # **Internet Article Traffic Prediction**

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import jieba
from datetime import datetime
from textblob import TextBlob
import emoji
import re
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
import tensorflow as tf
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ## Read Data

# %%
train = pd.read_csv('./data/train_dataset.csv')
test = pd.read_csv('./data/test_dataset.csv')

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# 1. 標題hashtag分類

# %%
def preprocessor(text):   # Remove the number in the titles and return the word after hashtag
    number = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0']
    for i in number:
        text = text.replace(i, '')
    out = ''
    hash_index = text.find('#')
    if hash_index != -1: 
        space_index = text.find(' ', hash_index)
        if space_index != -1: 
            out = text[hash_index+1:space_index]
        else: 
            out = text[hash_index+1:]
    if len(out) > 5: out = ''   # Only take the hashtag name that is shorter or equal to five chars
    return out

def text_count_vectorizer(data):   # Return the count vectorizer model based on the input data
    transfer = CountVectorizer(preprocessor=preprocessor)
    transfer.fit(data)
    return transfer

bag = train['title']
vectorizer = text_count_vectorizer(bag)

test_case_1 = '#上榜心得 123'
test_case_1_vectorized = vectorizer.transform([test_case_1])

def title_into_hash(title, vectorizer):   # Use the vectorizer to transorm the titles into vectors and turn the vectors into hash values
    vec = vectorizer.transform([title]).toarray()[0]
    return hash(tuple(vec))
train['title_hash'] = train['title'].map(lambda x : title_into_hash(x, vectorizer))
test['title_hash'] = test['title'].map(lambda x : title_into_hash(x, vectorizer))

# Debug messages
# print("The first 50 hashtag name:\n", vectorizer.get_feature_names_out()[:50], '\n')
# print('Result of title vectorization of test case 1 \'#上榜心得 123\':\n', test_case_1_vectorized, '\n')
# print('Vector size after title vectorization:\n', test_case_1_vectorized.shape, '\n')
# print('The first 5 hash values of training set:\n',train['title_hash'][:5], '\n')
# print('The first 5 hash values of testing set:\n', test['title_hash'][:5])

# %% [markdown]
# 2. 星期幾以及時間區段

# %%
def weekday(time):   # Return 0 if Monday, 1 if Tuesday, ..., 6 if Sunday
    datetime_object = datetime.strptime(time[:-4], '%Y-%m-%d %H:%M:%S')
    return datetime_object.weekday()

def time_interval(time):   # Cut one day into 24 time interval, return which time interval the input time is in
    datetime_object = datetime.strptime(time[:-4], '%Y-%m-%d %H:%M:%S')
    return int(datetime_object.hour)

train['weekday'] = train['created_at'].map(lambda x : weekday(x))
test['weekday'] = test['created_at'].map(lambda x : weekday(x))
train['time_interval'] = train['created_at'].map(lambda x : time_interval(x))
test['time_interval'] = test['created_at'].map(lambda x : time_interval(x))

# %% [markdown]
# 3. 標題長度

# %%
def len_of_text(text):
    return len(text)

train['title_len'] = train['title'].map(lambda x : len_of_text(x))
test['title_len'] = test['title'].map(lambda x : len_of_text(x))

# %% [markdown]
# 4. 標題情感

# %%
def sub(title):   # Return the subjectivity of the title
    sent = TextBlob(title)
    subjectivity  = sent.subjectivity
    return subjectivity

def pol(title):   # Return the polarity of the title
    sent = TextBlob(title)
    polarity  = sent.polarity
    return polarity

train['sub'] = train['title'].map(lambda x : sub(x))
test['sub'] = test['title'].map(lambda x : sub(x))
train['pol'] = train['title'].map(lambda x : pol(x))
test['pol'] = test['title'].map(lambda x : pol(x))

# %% [markdown]
# 5. 標題是否包含emoji

# %%
def has_emoji(text):
    if any(char in emoji.EMOJI_DATA for char in text): return 1
    else: return 0

train['title_has_emoji'] = train['title'].map(lambda x : has_emoji(x))
test['title_has_emoji'] = test['title'].map(lambda x : has_emoji(x))

# %% [markdown]
# 6. 標題是否包含數字

# %%
def has_number(text):
    has_digit_number = re.search(r'\d', text)
    if has_digit_number: return 1
    else: return 0

train['title_has_number'] = train['title'].map(lambda x : has_number(x))
test['title_has_number'] = test['title'].map(lambda x : has_number(x))

# %% [markdown]
# ## Feature Interaction

# %% [markdown]
# 1. 按讚數與留言數：後續每一小時對於第一小時的斜率

# %%
train['like_diff_1'] = (train['like_count_2h'] - train['like_count_1h'])/1
train['like_diff_2'] = (train['like_count_3h'] - train['like_count_1h'])/2
train['like_diff_3'] = (train['like_count_4h'] - train['like_count_1h'])/3
train['like_diff_4'] = (train['like_count_5h'] - train['like_count_1h'])/4
train['like_diff_5'] = (train['like_count_6h'] - train['like_count_1h'])/5
test['like_diff_1'] = (test['like_count_2h'] - test['like_count_1h'])/1
test['like_diff_2'] = (test['like_count_3h'] - test['like_count_1h'])/2
test['like_diff_3'] = (test['like_count_4h'] - test['like_count_1h'])/3
test['like_diff_4'] = (test['like_count_5h'] - test['like_count_1h'])/4
test['like_diff_5'] = (test['like_count_6h'] - test['like_count_1h'])/5
train['comment_diff_1'] = (train['comment_count_2h'] - train['comment_count_1h'])/1
train['comment_diff_2'] = (train['comment_count_3h'] - train['comment_count_1h'])/2
train['comment_diff_3'] = (train['comment_count_4h'] - train['comment_count_1h'])/3
train['comment_diff_4'] = (train['comment_count_5h'] - train['comment_count_1h'])/4
train['comment_diff_5'] = (train['comment_count_6h'] - train['comment_count_1h'])/5
test['comment_diff_1'] = (test['comment_count_2h'] - test['comment_count_1h'])/1
test['comment_diff_2'] = (test['comment_count_3h'] - test['comment_count_1h'])/2
test['comment_diff_3'] = (test['comment_count_4h'] - test['comment_count_1h'])/3
test['comment_diff_4'] = (test['comment_count_5h'] - test['comment_count_1h'])/4
test['comment_diff_5'] = (test['comment_count_6h'] - test['comment_count_1h'])/5

# %% [markdown]
# 2. 按讚數與留言數：後一小時減掉前一小時

# %%
train['like_minus_1'] = train['like_count_2h'] - train['like_count_1h']
train['like_minus_2'] = train['like_count_3h'] - train['like_count_2h']
train['like_minus_3'] = train['like_count_4h'] - train['like_count_3h']
train['like_minus_4'] = train['like_count_5h'] - train['like_count_4h']
train['like_minus_5'] = train['like_count_6h'] - train['like_count_5h']
test['like_minus_1'] = test['like_count_2h'] - test['like_count_1h']
test['like_minus_2'] = test['like_count_3h'] - test['like_count_2h']
test['like_minus_3'] = test['like_count_4h'] - test['like_count_3h']
test['like_minus_4'] = test['like_count_5h'] - test['like_count_4h']
test['like_minus_5'] = test['like_count_6h'] - test['like_count_5h']
train['comment_minus_1'] = train['comment_count_2h'] - train['comment_count_1h']
train['comment_minus_2'] = train['comment_count_3h'] - train['comment_count_2h']
train['comment_minus_3'] = train['comment_count_4h'] - train['comment_count_3h']
train['comment_minus_4'] = train['comment_count_5h'] - train['comment_count_4h']
train['comment_minus_5'] = train['comment_count_6h'] - train['comment_count_5h']
test['comment_minus_1'] = test['comment_count_2h'] - test['comment_count_1h']
test['comment_minus_2'] = test['comment_count_3h'] - test['comment_count_2h']
test['comment_minus_3'] = test['comment_count_4h'] - test['comment_count_3h']
test['comment_minus_4'] = test['comment_count_5h'] - test['comment_count_4h']
test['comment_minus_5'] = test['comment_count_6h'] - test['comment_count_5h']

# %% [markdown]
# 3. 按讚數：截至這一小時的平均

# %%
train['like_avg_1'] = train['like_count_1h'] 
train['like_avg_2'] = (train['like_count_1h']+train['like_count_2h'])/2
train['like_avg_3'] = (train['like_count_1h']+train['like_count_2h']+train['like_count_3h'])/3
train['like_avg_4'] = (train['like_count_1h']+train['like_count_2h']+train['like_count_3h']+train['like_count_4h'])/4
train['like_avg_5'] = (train['like_count_1h']+train['like_count_2h']+train['like_count_3h']+train['like_count_4h']+train['like_count_5h'])/5
train['like_avg_6'] = (train['like_count_1h']+train['like_count_2h']+train['like_count_3h']+train['like_count_4h']+train['like_count_5h']+train['like_count_6h'])/6
test['like_avg_1'] = test['like_count_1h'] 
test['like_avg_2'] = (test['like_count_1h']+test['like_count_2h'])/2
test['like_avg_3'] = (test['like_count_1h']+test['like_count_2h']+test['like_count_3h'])/3
test['like_avg_4'] = (test['like_count_1h']+test['like_count_2h']+test['like_count_3h']+test['like_count_4h'])/4
test['like_avg_5'] = (test['like_count_1h']+test['like_count_2h']+test['like_count_3h']+test['like_count_4h']+test['like_count_5h'])/5
test['like_avg_6'] = (test['like_count_1h']+test['like_count_2h']+test['like_count_3h']+test['like_count_4h']+test['like_count_5h']+test['like_count_6h'])/6

# %% [markdown]
# 4. 按讚數：三小時移動平均（第一小時和第二小時採用截至這一小時平均）

# %%
train['like_move_avg_1'] = train['like_count_1h']/3
train['like_move_avg_2'] = (train['like_count_1h']+train['like_count_2h'])/3
train['like_move_avg_3'] = (train['like_count_1h']+train['like_count_2h']+train['like_count_3h'])/3
train['like_move_avg_4'] = (train['like_count_2h']+train['like_count_3h']+train['like_count_4h'])/3
train['like_move_avg_5'] = (train['like_count_3h']+train['like_count_4h']+train['like_count_5h'])/3
train['like_move_avg_6'] = (train['like_count_4h']+train['like_count_5h']+train['like_count_6h'])/3
test['like_move_avg_1'] = test['like_count_1h']/3
test['like_move_avg_2'] = (test['like_count_1h']+test['like_count_2h'])/3
test['like_move_avg_3'] = (test['like_count_1h']+test['like_count_2h']+test['like_count_3h'])/3
test['like_move_avg_4'] = (test['like_count_2h']+test['like_count_3h']+test['like_count_4h'])/3
test['like_move_avg_5'] = (test['like_count_3h']+test['like_count_4h']+test['like_count_5h'])/3
test['like_move_avg_6'] = (test['like_count_4h']+test['like_count_5h']+test['like_count_6h'])/3

# %% [markdown]
# ## Generate Training Set and Testing Set for the Model

# %%
x_train = np.array(train.drop(['title', 'created_at', 'like_count_24h'], axis=1))
y_train = np.array(train['like_count_24h'])
x_test = np.array(test.drop(['title', 'created_at', 'like_count_24h'], axis=1))
y_test = np.array(test['like_count_24h'])

# Standarlize all the feature
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# x_train shape: (50000, 55)
# x_test shape: (10000, 55)

# %% [markdown]
# ## DNN Model

# %%
def MAPE(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    ape = tf.abs((y_true - y_pred) / y_true)
    mape = tf.reduce_mean(ape)
    return mape

model = Sequential()

model.add(Dense(75, activation="relu", input_shape=x_train.shape[1:]))
model.add(Dense(100, activation="relu"))
model.add(Dense(180, activation="relu"))
model.add(Dense(250, activation="relu"))
model.add(Dense(500, activation="relu"))
model.add(Dense(350, activation="relu"))
model.add(Dense(200, activation="relu"))
model.add(Dense(100, activation="relu"))
model.add(Dense(48, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(4, activation="relu"))
model.add(Dense(1))

model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.001), metrics=[MAPE])

model.summary()

checkpoint = ModelCheckpoint(filepath='best_model.h5',  # 存放最佳模型的檔案名稱
                             monitor='val_MAPE',  # 監視的指標
                             save_best_only=True,  # 只保存最佳模型
                             save_weights_only=False,  # 是否只保存模型的權重
                             mode='min',  # 監視指標的模式，這裡使用 'min' 表示監視損失函數值的最小值
                             verbose=1)  # 顯示保存模型的信息

early_stopping = EarlyStopping(monitor='val_MAPE', patience=60)

model.fit(x_train, y_train, epochs=600, batch_size=128, shuffle=True, validation_data=(x_test, y_test), callbacks=[early_stopping, checkpoint])
model.load_weights('best_model.h5')
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_219 (Dense)           (None, 75)                4200
#
#  dense_220 (Dense)           (None, 100)               7600
#
#  dense_221 (Dense)           (None, 180)               18180
#
#  dense_222 (Dense)           (None, 250)               45250
#
#  dense_223 (Dense)           (None, 500)               125500
#
#  dense_224 (Dense)           (None, 350)               175350
#
#  dense_225 (Dense)           (None, 200)               70200
#
#  dense_226 (Dense)           (None, 100)               20100
#
#  dense_227 (Dense)           (None, 48)                4848
#
#  dense_228 (Dense)           (None, 16)                784
#
#  dense_229 (Dense)           (None, 4)                 68
#
#  dense_230 (Dense)           (None, 1)                 5
#
# =================================================================
# Total params: 472,085
# Trainable params: 472,085
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/600
# 388/391 [============================>.] - ETA: 0s - loss: 22.0840 - MAPE: 0.4554
# Epoch 1: val_MAPE improved from inf to 0.38615, saving model to best_model.h5
# 391/391 [==============================] - 3s 5ms/step - loss: 22.0298 - MAPE: 0.4556 - val_loss: 20.8545 - val_MAPE: 0.3862
# Epoch 2/600
# 388/391 [============================>.] - ETA: 0s - loss: 18.8556 - MAPE: 0.3580
# Epoch 2: val_MAPE improved from 0.38615 to 0.36131, saving model to best_model.h5
# 391/391 [==============================] - 2s 6ms/step - loss: 18.8261 - MAPE: 0.3582 - val_loss: 19.9913 - val_MAPE: 0.3613
# Epoch 3/600
# 388/391 [============================>.] - ETA: 0s - loss: 18.5714 - MAPE: 0.3531
# Epoch 3: val_MAPE did not improve from 0.36131
# 391/391 [==============================] - 3s 7ms/step - loss: 18.5472 - MAPE: 0.3529 - val_loss: 23.5623 - val_MAPE: 0.4190
# Epoch 4/600
# 391/391 [==============================] - ETA: 0s - loss: 18.4823 - MAPE: 0.3538
# Epoch 4: val_MAPE did not improve from 0.36131
# 391/391 [==============================] - 3s 8ms/step - loss: 18.4823 - MAPE: 0.3538 - val_loss: 19.8223 - val_MAPE: 0.3761
# Epoch 5/600
# 385/391 [============================>.] - ETA: 0s - loss: 17.9372 - MAPE: 0.3439
# Epoch 5: val_MAPE did not improve from 0.36131
# 391/391 [==============================] - 3s 7ms/step - loss: 17.9877 - MAPE: 0.3437 - val_loss: 20.6636 - val_MAPE: 0.4570
# Epoch 6/600
# 384/391 [============================>.] - ETA: 0s - loss: 17.9220 - MAPE: 0.3395
# Epoch 6: val_MAPE improved from 0.36131 to 0.33141, saving model to best_model.h5
# 391/391 [==============================] - 3s 8ms/step - loss: 17.9846 - MAPE: 0.3400 - val_loss: 19.1098 - val_MAPE: 0.3314
# Epoch 7/600
# 385/391 [============================>.] - ETA: 0s - loss: 17.7099 - MAPE: 0.3373
# Epoch 7: val_MAPE did not improve from 0.33141
# 391/391 [==============================] - 3s 8ms/step - loss: 17.7064 - MAPE: 0.3368 - val_loss: 19.1384 - val_MAPE: 0.3391
# Epoch 8/600
# 388/391 [============================>.] - ETA: 0s - loss: 17.9926 - MAPE: 0.3399
# Epoch 8: val_MAPE improved from 0.33141 to 0.32217, saving model to best_model.h5
# 391/391 [==============================] - 3s 8ms/step - loss: 17.9497 - MAPE: 0.3402 - val_loss: 19.5175 - val_MAPE: 0.3222
# Epoch 9/600
# 386/391 [============================>.] - ETA: 0s - loss: 17.4996 - MAPE: 0.3354
# Epoch 9: val_MAPE improved from 0.32217 to 0.31702, saving model to best_model.h5
# 391/391 [==============================] - 3s 8ms/step - loss: 17.4715 - MAPE: 0.3349 - val_loss: 19.7005 - val_MAPE: 0.3170
# Epoch 10/600
# 384/391 [============================>.] - ETA: 0s - loss: 17.3545 - MAPE: 0.3288
# Epoch 10: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 8ms/step - loss: 17.3036 - MAPE: 0.3289 - val_loss: 19.1712 - val_MAPE: 0.3191
# Epoch 11/600
# 388/391 [============================>.] - ETA: 0s - loss: 17.2447 - MAPE: 0.3307
# Epoch 11: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 8ms/step - loss: 17.2427 - MAPE: 0.3313 - val_loss: 18.6524 - val_MAPE: 0.3889
# Epoch 12/600
# 384/391 [============================>.] - ETA: 0s - loss: 17.0949 - MAPE: 0.3280
# Epoch 12: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 7ms/step - loss: 17.0574 - MAPE: 0.3287 - val_loss: 18.8294 - val_MAPE: 0.3451
# Epoch 13/600
# 387/391 [============================>.] - ETA: 0s - loss: 17.1032 - MAPE: 0.3292
# Epoch 13: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 9ms/step - loss: 17.1615 - MAPE: 0.3293 - val_loss: 18.6793 - val_MAPE: 0.3271
# Epoch 14/600
# 389/391 [============================>.] - ETA: 0s - loss: 17.0323 - MAPE: 0.3294
# Epoch 14: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 9ms/step - loss: 17.0340 - MAPE: 0.3292 - val_loss: 18.7370 - val_MAPE: 0.3389
# Epoch 15/600
# 387/391 [============================>.] - ETA: 0s - loss: 16.8829 - MAPE: 0.3219
# Epoch 15: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 9ms/step - loss: 16.8454 - MAPE: 0.3219 - val_loss: 19.3401 - val_MAPE: 0.3243
# Epoch 16/600
# 388/391 [============================>.] - ETA: 0s - loss: 17.1101 - MAPE: 0.3309
# Epoch 16: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 10ms/step - loss: 17.0850 - MAPE: 0.3309 - val_loss: 18.3817 - val_MAPE: 0.3658
# Epoch 17/600
# 386/391 [============================>.] - ETA: 0s - loss: 17.0147 - MAPE: 0.3256
# Epoch 17: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 9ms/step - loss: 16.9858 - MAPE: 0.3260 - val_loss: 18.7090 - val_MAPE: 0.3586
# Epoch 18/600
# 387/391 [============================>.] - ETA: 0s - loss: 16.8419 - MAPE: 0.3208
# Epoch 18: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 9ms/step - loss: 16.8228 - MAPE: 0.3209 - val_loss: 19.1192 - val_MAPE: 0.3748
# Epoch 19/600
# 388/391 [============================>.] - ETA: 0s - loss: 16.8218 - MAPE: 0.3245
# Epoch 19: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 10ms/step - loss: 16.7775 - MAPE: 0.3241 - val_loss: 18.6164 - val_MAPE: 0.3264
# Epoch 20/600
# 391/391 [==============================] - ETA: 0s - loss: 16.7195 - MAPE: 0.3221
# Epoch 20: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 4s 11ms/step - loss: 16.7195 - MAPE: 0.3221 - val_loss: 19.3940 - val_MAPE: 0.3645
# Epoch 21/600
# 388/391 [============================>.] - ETA: 0s - loss: 16.4053 - MAPE: 0.3160
# Epoch 21: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 8ms/step - loss: 16.4534 - MAPE: 0.3165 - val_loss: 19.6792 - val_MAPE: 0.3604
# Epoch 22/600
# 388/391 [============================>.] - ETA: 0s - loss: 16.5454 - MAPE: 0.3245
# Epoch 22: val_MAPE did not improve from 0.31702
# 391/391 [==============================] - 3s 7ms/step - loss: 16.6252 - MAPE: 0.3249 - val_loss: 18.7446 - val_MAPE: 0.3807
# Epoch 23/600
# 387/391 [============================>.] - ETA: 0s - loss: 16.5896 - MAPE: 0.3193
# Epoch 23: val_MAPE improved from 0.31702 to 0.31621, saving model to best_model.h5
# 391/391 [==============================] - 3s 9ms/step - loss: 16.5762 - MAPE: 0.3189 - val_loss: 20.1277 - val_MAPE: 0.3162
# Epoch 24/600
# 386/391 [============================>.] - ETA: 0s - loss: 16.2523 - MAPE: 0.3161
# Epoch 24: val_MAPE did not improve from 0.31621
# 391/391 [==============================] - 3s 7ms/step - loss: 16.2395 - MAPE: 0.3158 - val_loss: 19.6076 - val_MAPE: 0.3478
# Epoch 25/600
# 387/391 [============================>.] - ETA: 0s - loss: 16.3036 - MAPE: 0.3157
# Epoch 25: val_MAPE did not improve from 0.31621
# 391/391 [==============================] - 3s 7ms/step - loss: 16.3024 - MAPE: 0.3158 - val_loss: 19.3367 - val_MAPE: 0.3548
# Epoch 26/600
# 389/391 [============================>.] - ETA: 0s - loss: 16.1562 - MAPE: 0.3160
# Epoch 26: val_MAPE did not improve from 0.31621
# 391/391 [==============================] - 4s 10ms/step - loss: 16.1734 - MAPE: 0.3159 - val_loss: 19.5222 - val_MAPE: 0.3315
# Epoch 27/600
# 389/391 [============================>.] - ETA: 0s - loss: 16.0820 - MAPE: 0.3172
# Epoch 27: val_MAPE did not improve from 0.31621
# 391/391 [==============================] - 3s 8ms/step - loss: 16.0896 - MAPE: 0.3171 - val_loss: 19.2581 - val_MAPE: 0.3410
# Epoch 28/600
# 388/391 [============================>.] - ETA: 0s - loss: 15.9613 - MAPE: 0.3161
# Epoch 28: val_MAPE did not improve from 0.31621
# 391/391 [==============================] - 3s 8ms/step - loss: 15.9749 - MAPE: 0.3161 - val_loss: 21.7312 - val_MAPE: 0.3352
# Epoch 29/600
# 385/391 [============================>.] - ETA: 0s - loss: 15.9865 - MAPE: 0.3139
# Epoch 29: val_MAPE improved from 0.31621 to 0.31518, saving model to best_model.h5
# 391/391 [==============================] - 3s 8ms/step - loss: 15.9624 - MAPE: 0.3134 - val_loss: 20.1043 - val_MAPE: 0.3152
# Epoch 30/600
# 386/391 [============================>.] - ETA: 0s - loss: 16.3635 - MAPE: 0.3174
# Epoch 30: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 9ms/step - loss: 16.3414 - MAPE: 0.3176 - val_loss: 19.0623 - val_MAPE: 0.3248
# Epoch 31/600
# 386/391 [============================>.] - ETA: 0s - loss: 16.0444 - MAPE: 0.3145
# Epoch 31: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 16.0212 - MAPE: 0.3146 - val_loss: 18.7011 - val_MAPE: 0.3421
# Epoch 32/600
# 389/391 [============================>.] - ETA: 0s - loss: 15.5095 - MAPE: 0.3095
# Epoch 32: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.5139 - MAPE: 0.3094 - val_loss: 20.2650 - val_MAPE: 0.3199
# Epoch 33/600
# 383/391 [============================>.] - ETA: 0s - loss: 15.6980 - MAPE: 0.3141
# Epoch 33: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.6346 - MAPE: 0.3136 - val_loss: 18.9515 - val_MAPE: 0.3391
# Epoch 34/600
# 387/391 [============================>.] - ETA: 0s - loss: 15.7935 - MAPE: 0.3142
# Epoch 34: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 6ms/step - loss: 15.7721 - MAPE: 0.3139 - val_loss: 18.5104 - val_MAPE: 0.3532
# Epoch 35/600
# 388/391 [============================>.] - ETA: 0s - loss: 15.5813 - MAPE: 0.3126
# Epoch 35: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.6039 - MAPE: 0.3133 - val_loss: 18.7406 - val_MAPE: 0.3991
# Epoch 36/600
# 386/391 [============================>.] - ETA: 0s - loss: 15.5249 - MAPE: 0.3129
# Epoch 36: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.5001 - MAPE: 0.3127 - val_loss: 18.5961 - val_MAPE: 0.3714
# Epoch 37/600
# 390/391 [============================>.] - ETA: 0s - loss: 15.3556 - MAPE: 0.3105
# Epoch 37: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.3601 - MAPE: 0.3106 - val_loss: 20.5862 - val_MAPE: 0.3304
# Epoch 38/600
# 384/391 [============================>.] - ETA: 0s - loss: 15.3203 - MAPE: 0.3098
# Epoch 38: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.3644 - MAPE: 0.3103 - val_loss: 19.1178 - val_MAPE: 0.3502
# Epoch 39/600
# 388/391 [============================>.] - ETA: 0s - loss: 15.4897 - MAPE: 0.3119
# Epoch 39: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 6ms/step - loss: 15.4891 - MAPE: 0.3117 - val_loss: 19.5599 - val_MAPE: 0.3231
# Epoch 40/600
# 384/391 [============================>.] - ETA: 0s - loss: 15.1862 - MAPE: 0.3097
# Epoch 40: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.1618 - MAPE: 0.3100 - val_loss: 18.9977 - val_MAPE: 0.3357
# Epoch 41/600
# 384/391 [============================>.] - ETA: 0s - loss: 15.1300 - MAPE: 0.3087
# Epoch 41: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 15.1342 - MAPE: 0.3085 - val_loss: 18.2502 - val_MAPE: 0.3410
# Epoch 42/600
# 386/391 [============================>.] - ETA: 0s - loss: 15.0019 - MAPE: 0.3059
# Epoch 42: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 15.0396 - MAPE: 0.3061 - val_loss: 18.6421 - val_MAPE: 0.3590
# Epoch 43/600
# 389/391 [============================>.] - ETA: 0s - loss: 15.0243 - MAPE: 0.3081
# Epoch 43: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.0256 - MAPE: 0.3083 - val_loss: 18.8019 - val_MAPE: 0.3547
# Epoch 44/600
# 386/391 [============================>.] - ETA: 0s - loss: 15.1502 - MAPE: 0.3083
# Epoch 44: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 15.1226 - MAPE: 0.3080 - val_loss: 19.1860 - val_MAPE: 0.3263
# Epoch 45/600
# 389/391 [============================>.] - ETA: 0s - loss: 14.9584 - MAPE: 0.3054
# Epoch 45: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 14.9469 - MAPE: 0.3054 - val_loss: 19.5225 - val_MAPE: 0.3310
# Epoch 46/600
# 385/391 [============================>.] - ETA: 0s - loss: 14.7057 - MAPE: 0.3060
# Epoch 46: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 14.7688 - MAPE: 0.3054 - val_loss: 20.0947 - val_MAPE: 0.3220
# Epoch 47/600
# 386/391 [============================>.] - ETA: 0s - loss: 14.8350 - MAPE: 0.3066
# Epoch 47: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 14.8025 - MAPE: 0.3066 - val_loss: 19.9685 - val_MAPE: 0.3518
# Epoch 48/600
# 386/391 [============================>.] - ETA: 0s - loss: 14.6101 - MAPE: 0.3043
# Epoch 48: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 14.6516 - MAPE: 0.3047 - val_loss: 18.5656 - val_MAPE: 0.3552
# Epoch 49/600
# 389/391 [============================>.] - ETA: 0s - loss: 14.7091 - MAPE: 0.3080
# Epoch 49: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.7009 - MAPE: 0.3079 - val_loss: 18.5953 - val_MAPE: 0.3357
# Epoch 50/600
# 384/391 [============================>.] - ETA: 0s - loss: 14.5703 - MAPE: 0.3024
# Epoch 50: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 14.5713 - MAPE: 0.3031 - val_loss: 18.7111 - val_MAPE: 0.3451
# Epoch 51/600
# 391/391 [==============================] - ETA: 0s - loss: 14.4071 - MAPE: 0.3026
# Epoch 51: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 14.4071 - MAPE: 0.3026 - val_loss: 18.5879 - val_MAPE: 0.3562
# Epoch 52/600
# 387/391 [============================>.] - ETA: 0s - loss: 14.7207 - MAPE: 0.3058
# Epoch 52: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.6981 - MAPE: 0.3055 - val_loss: 19.0948 - val_MAPE: 0.3286
# Epoch 53/600
# 386/391 [============================>.] - ETA: 0s - loss: 14.6721 - MAPE: 0.3043
# Epoch 53: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 9ms/step - loss: 14.6783 - MAPE: 0.3046 - val_loss: 18.7232 - val_MAPE: 0.3582
# Epoch 54/600
# 390/391 [============================>.] - ETA: 0s - loss: 14.4461 - MAPE: 0.3030
# Epoch 54: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 9ms/step - loss: 14.4381 - MAPE: 0.3030 - val_loss: 18.7406 - val_MAPE: 0.3323
# Epoch 55/600
# 389/391 [============================>.] - ETA: 0s - loss: 14.3748 - MAPE: 0.3015
# Epoch 55: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 14.3673 - MAPE: 0.3017 - val_loss: 20.3096 - val_MAPE: 0.3419
# Epoch 56/600
# 391/391 [==============================] - ETA: 0s - loss: 14.6843 - MAPE: 0.3046
# Epoch 56: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 14.6843 - MAPE: 0.3046 - val_loss: 18.9724 - val_MAPE: 0.3188
# Epoch 57/600
# 389/391 [============================>.] - ETA: 0s - loss: 14.2748 - MAPE: 0.3009
# Epoch 57: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.2576 - MAPE: 0.3007 - val_loss: 18.7519 - val_MAPE: 0.3254
# Epoch 58/600
# 388/391 [============================>.] - ETA: 0s - loss: 14.1054 - MAPE: 0.3019
# Epoch 58: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.0912 - MAPE: 0.3017 - val_loss: 19.4213 - val_MAPE: 0.3466
# Epoch 59/600
# 386/391 [============================>.] - ETA: 0s - loss: 14.1744 - MAPE: 0.3028
# Epoch 59: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 14.1797 - MAPE: 0.3031 - val_loss: 18.9991 - val_MAPE: 0.3218
# Epoch 60/600
# 390/391 [============================>.] - ETA: 0s - loss: 14.1555 - MAPE: 0.3022
# Epoch 60: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.1477 - MAPE: 0.3024 - val_loss: 19.1898 - val_MAPE: 0.3737
# Epoch 61/600
# 390/391 [============================>.] - ETA: 0s - loss: 14.0257 - MAPE: 0.2974
# Epoch 61: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 14.0208 - MAPE: 0.2975 - val_loss: 19.2285 - val_MAPE: 0.3418
# Epoch 62/600
# 390/391 [============================>.] - ETA: 0s - loss: 14.0633 - MAPE: 0.2984
# Epoch 62: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 14.0576 - MAPE: 0.2985 - val_loss: 18.8431 - val_MAPE: 0.3313
# Epoch 63/600
# 388/391 [============================>.] - ETA: 0s - loss: 13.7814 - MAPE: 0.2975
# Epoch 63: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.8167 - MAPE: 0.2974 - val_loss: 18.8142 - val_MAPE: 0.3723
# Epoch 64/600
# 388/391 [============================>.] - ETA: 0s - loss: 13.6829 - MAPE: 0.2968
# Epoch 64: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 10ms/step - loss: 13.6891 - MAPE: 0.2969 - val_loss: 19.6802 - val_MAPE: 0.3306
# Epoch 65/600
# 386/391 [============================>.] - ETA: 0s - loss: 13.6600 - MAPE: 0.2993
# Epoch 65: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 10ms/step - loss: 13.6505 - MAPE: 0.2994 - val_loss: 18.5071 - val_MAPE: 0.3374
# Epoch 66/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.7316 - MAPE: 0.2976
# Epoch 66: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.7275 - MAPE: 0.2975 - val_loss: 20.0057 - val_MAPE: 0.3312
# Epoch 67/600
# 388/391 [============================>.] - ETA: 0s - loss: 13.5355 - MAPE: 0.2960
# Epoch 67: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 9ms/step - loss: 13.5273 - MAPE: 0.2960 - val_loss: 18.5263 - val_MAPE: 0.3518
# Epoch 68/600
# 391/391 [==============================] - ETA: 0s - loss: 13.7041 - MAPE: 0.2981
# Epoch 68: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.7041 - MAPE: 0.2981 - val_loss: 18.6407 - val_MAPE: 0.3409
# Epoch 69/600
# 391/391 [==============================] - ETA: 0s - loss: 13.5154 - MAPE: 0.2953
# Epoch 69: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.5154 - MAPE: 0.2953 - val_loss: 18.5876 - val_MAPE: 0.3281
# Epoch 70/600
# 384/391 [============================>.] - ETA: 0s - loss: 13.7268 - MAPE: 0.2967
# Epoch 70: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 9ms/step - loss: 13.7051 - MAPE: 0.2965 - val_loss: 18.8528 - val_MAPE: 0.3318
# Epoch 71/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.4898 - MAPE: 0.2944
# Epoch 71: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.4964 - MAPE: 0.2945 - val_loss: 18.6619 - val_MAPE: 0.3469
# Epoch 72/600
# 385/391 [============================>.] - ETA: 0s - loss: 13.3984 - MAPE: 0.2948
# Epoch 72: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 13.3655 - MAPE: 0.2948 - val_loss: 18.5590 - val_MAPE: 0.3331
# Epoch 73/600
# 391/391 [==============================] - ETA: 0s - loss: 13.2512 - MAPE: 0.2946
# Epoch 73: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 10ms/step - loss: 13.2512 - MAPE: 0.2946 - val_loss: 18.7688 - val_MAPE: 0.3415
# Epoch 74/600
# 391/391 [==============================] - ETA: 0s - loss: 13.3505 - MAPE: 0.2938
# Epoch 74: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 13.3505 - MAPE: 0.2938 - val_loss: 19.0957 - val_MAPE: 0.3471
# Epoch 75/600
# 390/391 [============================>.] - ETA: 0s - loss: 12.9851 - MAPE: 0.2906
# Epoch 75: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 10ms/step - loss: 12.9817 - MAPE: 0.2906 - val_loss: 18.6853 - val_MAPE: 0.3399
# Epoch 76/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.1025 - MAPE: 0.2911
# Epoch 76: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 10ms/step - loss: 13.0961 - MAPE: 0.2911 - val_loss: 19.3736 - val_MAPE: 0.3268
# Epoch 77/600
# 388/391 [============================>.] - ETA: 0s - loss: 13.0553 - MAPE: 0.2916
# Epoch 77: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 9ms/step - loss: 13.0614 - MAPE: 0.2915 - val_loss: 21.1381 - val_MAPE: 0.3288
# Epoch 78/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.3372 - MAPE: 0.2947
# Epoch 78: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 4s 11ms/step - loss: 13.3368 - MAPE: 0.2949 - val_loss: 19.0623 - val_MAPE: 0.3387
# Epoch 79/600
# 384/391 [============================>.] - ETA: 0s - loss: 12.9269 - MAPE: 0.2897
# Epoch 79: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.9629 - MAPE: 0.2902 - val_loss: 18.9086 - val_MAPE: 0.3389
# Epoch 80/600
# 391/391 [==============================] - ETA: 0s - loss: 13.1074 - MAPE: 0.2908
# Epoch 80: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 13.1074 - MAPE: 0.2908 - val_loss: 18.7843 - val_MAPE: 0.3471
# Epoch 81/600
# 387/391 [============================>.] - ETA: 0s - loss: 12.8904 - MAPE: 0.2923
# Epoch 81: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.8923 - MAPE: 0.2921 - val_loss: 19.1172 - val_MAPE: 0.3276
# Epoch 82/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.2860 - MAPE: 0.2966
# Epoch 82: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 13.3260 - MAPE: 0.2964 - val_loss: 18.6867 - val_MAPE: 0.3468
# Epoch 83/600
# 390/391 [============================>.] - ETA: 0s - loss: 13.0066 - MAPE: 0.2908
# Epoch 83: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 13.0087 - MAPE: 0.2907 - val_loss: 18.7849 - val_MAPE: 0.3325
# Epoch 84/600
# 388/391 [============================>.] - ETA: 0s - loss: 12.7441 - MAPE: 0.2901
# Epoch 84: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 7ms/step - loss: 12.7790 - MAPE: 0.2902 - val_loss: 18.8274 - val_MAPE: 0.3444
# Epoch 85/600
# 386/391 [============================>.] - ETA: 0s - loss: 12.8216 - MAPE: 0.2913
# Epoch 85: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.8027 - MAPE: 0.2908 - val_loss: 19.0112 - val_MAPE: 0.3411
# Epoch 86/600
# 390/391 [============================>.] - ETA: 0s - loss: 12.8861 - MAPE: 0.2897
# Epoch 86: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.9311 - MAPE: 0.2897 - val_loss: 19.2005 - val_MAPE: 0.3770
# Epoch 87/600
# 385/391 [============================>.] - ETA: 0s - loss: 12.8593 - MAPE: 0.2913
# Epoch 87: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.8429 - MAPE: 0.2914 - val_loss: 19.2088 - val_MAPE: 0.3683
# Epoch 88/600
# 383/391 [============================>.] - ETA: 0s - loss: 12.5838 - MAPE: 0.2886
# Epoch 88: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.5402 - MAPE: 0.2886 - val_loss: 18.4526 - val_MAPE: 0.3471
# Epoch 89/600
# 387/391 [============================>.] - ETA: 0s - loss: 12.8760 - MAPE: 0.2905
# Epoch 89: val_MAPE did not improve from 0.31518
# 391/391 [==============================] - 3s 8ms/step - loss: 12.9054 - MAPE: 0.2906 - val_loss: 19.0380 - val_MAPE: 0.3701

# %% [markdown]
# ## Evaluation

# %%
def MAPE(predict, real):
    validation_num = predict.shape[0]
    total = 0
    for i in range(validation_num):
        total += abs(predict[i]-real[i])/real[i]
    return total/validation_num

pre_train = model.predict(x_train)
pre_test = model.predict(x_test)

print('訓練集: ',MAPE(pre_train, y_train))
print('測試集: ',MAPE(pre_test, y_test))
# Out:
# 1563/1563 [==============================] - 1s 839us/step
# 313/313 [==============================] - 0s 807us/step
# 訓練集:  [0.28179666]
# 測試集:  [0.315641]

# %% [markdown]
# ## Predict

# %%
private_test = pd.read_csv('./data/intern_homework_private_test_dataset.csv')
private_test['title_hash'] = private_test['title'].map(lambda x : title_into_hash(x, vectorizer))
private_test['weekday'] = private_test['created_at'].map(lambda x : weekday(x))
private_test['time_interval'] = private_test['created_at'].map(lambda x : time_interval(x))
private_test['title_len'] = private_test['title'].map(lambda x : len_of_text(x))
private_test['sub'] = private_test['title'].map(lambda x : sub(x))
private_test['pol'] = private_test['title'].map(lambda x : pol(x))
private_test['title_has_emoji'] = private_test['title'].map(lambda x : has_emoji(x))
private_test['title_has_number'] = private_test['title'].map(lambda x : has_number(x))
private_test['like_diff_1'] = (private_test['like_count_2h'] - private_test['like_count_1h'])/1
private_test['like_diff_2'] = (private_test['like_count_3h'] - private_test['like_count_1h'])/2
private_test['like_diff_3'] = (private_test['like_count_4h'] - private_test['like_count_1h'])/3
private_test['like_diff_4'] = (private_test['like_count_5h'] - private_test['like_count_1h'])/4
private_test['like_diff_5'] = (private_test['like_count_6h'] - private_test['like_count_1h'])/5
private_test['comment_diff_1'] = (private_test['comment_count_2h'] - private_test['comment_count_1h'])/1
private_test['comment_diff_2'] = (private_test['comment_count_3h'] - private_test['comment_count_1h'])/2
private_test['comment_diff_3'] = (private_test['comment_count_4h'] - private_test['comment_count_1h'])/3
private_test['comment_diff_4'] = (private_test['comment_count_5h'] - private_test['comment_count_1h'])/4
private_test['comment_diff_5'] = (private_test['comment_count_6h'] - private_test['comment_count_1h'])/5
private_test['like_minus_1'] = private_test['like_count_2h'] - private_test['like_count_1h']
private_test['like_minus_2'] = private_test['like_count_3h'] - private_test['like_count_2h']
private_test['like_minus_3'] = private_test['like_count_4h'] - private_test['like_count_3h']
private_test['like_minus_4'] = private_test['like_count_5h'] - private_test['like_count_4h']
private_test['like_minus_5'] = private_test['like_count_6h'] - private_test['like_count_5h']
private_test['comment_minus_1'] = private_test['comment_count_2h'] - private_test['comment_count_1h']
private_test['comment_minus_2'] = private_test['comment_count_3h'] - private_test['comment_count_2h']
private_test['comment_minus_3'] = private_test['comment_count_4h'] - private_test['comment_count_3h']
private_test['comment_minus_4'] = private_test['comment_count_5h'] - private_test['comment_count_4h']
private_test['comment_minus_5'] = private_test['comment_count_6h'] - private_test['comment_count_5h']
private_test['like_avg_1'] = private_test['like_count_1h'] 
private_test['like_avg_2'] = (private_test['like_count_1h']+private_test['like_count_2h'])/2
private_test['like_avg_3'] = (private_test['like_count_1h']+private_test['like_count_2h']+private_test['like_count_3h'])/3
private_test['like_avg_4'] = (private_test['like_count_1h']+private_test['like_count_2h']+private_test['like_count_3h']+private_test['like_count_4h'])/4
private_test['like_avg_5'] = (private_test['like_count_1h']+private_test['like_count_2h']+private_test['like_count_3h']+private_test['like_count_4h']+private_test['like_count_5h'])/5
private_test['like_avg_6'] = (private_test['like_count_1h']+private_test['like_count_2h']+private_test['like_count_3h']+private_test['like_count_4h']+private_test['like_count_5h']+private_test['like_count_6h'])/6
private_test['like_move_avg_1'] = private_test['like_count_1h']/3
private_test['like_move_avg_2'] = (private_test['like_count_1h']+private_test['like_count_2h'])/3
private_test['like_move_avg_3'] = (private_test['like_count_1h']+private_test['like_count_2h']+private_test['like_count_3h'])/3
private_test['like_move_avg_4'] = (private_test['like_count_2h']+private_test['like_count_3h']+private_test['like_count_4h'])/3
private_test['like_move_avg_5'] = (private_test['like_count_3h']+private_test['like_count_4h']+private_test['like_count_5h'])/3
private_test['like_move_avg_6'] = (private_test['like_count_4h']+private_test['like_count_5h']+private_test['like_count_6h'])/3
private_test = private_test.drop(['title', 'created_at'], axis=1)
private_test = np.array(private_test)
private_test = scaler.transform(private_test)
print('private_test shape:', private_test.shape)
predict_private_test = model.predict(private_test)
result = pd.DataFrame(predict_private_test)
result.columns = ['like_count_24h']
result['like_count_24h'] = result['like_count_24h'].map(lambda x: round(x))
result.to_csv('data/result.csv', index = False)
# Out:
# private_test shape: (10000, 55)
# 313/313 [==============================] - 0s 827us/step
